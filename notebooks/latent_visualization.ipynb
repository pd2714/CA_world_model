# %% [markdown]
# # Latent Visualization
#
# Load a trained checkpoint, visualize the latent space, and run linear probes on observables.

# %%
run_dir = '../outputs/YOUR_RUN_DIR'
checkpoint = f'{run_dir}/best.ckpt'
config = '../configs/experiment/rule184_dense.yaml'

# %%
# !python -m src.scripts.visualize_latent --checkpoint {checkpoint} --config {config}
# !python -m src.scripts.run_probe_analysis --checkpoint {checkpoint} --config {config}

# %%
from PIL import Image
Image.open(f'{run_dir}/latent_viz/latent_pca.png')
