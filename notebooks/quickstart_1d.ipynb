# %% [markdown]
# # Quickstart 1D
#
# Minimal walkthrough for generating data, training a small model, and comparing rollout quality.

# %%
from src.utils.config import load_config
from src.utils.factory import generate_trajectories
from src.ca.visualization import plot_1d_trajectory

config = load_config('../configs/experiment/rule184_dense.yaml')
trajectories, metadata = generate_trajectories(config, 'test')
plot_1d_trajectory(trajectories[0, :, 0], title='Rule 184 sample');

# %%
# !python -m src.scripts.generate_data --config configs/experiment/rule184_dense.yaml
# !python -m src.scripts.train --config configs/experiment/rule184_dense.yaml

# %%
# Replace with your actual run directory after training.
run_dir = 'outputs/YOUR_RUN_DIR'
# !python -m src.scripts.evaluate --checkpoint {run_dir}/best.ckpt --config configs/experiment/rule184_dense.yaml
# !python -m src.scripts.compare_to_rule --checkpoint {run_dir}/best.ckpt --config configs/experiment/rule184_dense.yaml
